# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
from numpy import mean
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn import model_selection

# ##### kfold cross validation ################
from sklearn.model_selection import RepeatedStratifiedKFold

# %% [markdown]
# ## Read Dataset

# %%
# Load Dataset

data = pd.read_excel('drive/My Drive/Colab Notebooks/WisconsinDataset/Forms_cleaned.xlsx', 'form1')

print('\n\nDataset:')
print('========\n')
data
# Out:
# Dataset:
# ========
#           EID FormID  Flagged  Attempt  tot_time  iresp.1  iresp.2  iresp.3  \
# 0     e100001  form1        0        5     10133        1        1      3.0
# 1     e100002  form1        1        1     12409        1        3      3.0
# 2     e100003  form1        1        1     12457        2        3      4.0
# 3     e100004  form1        1        3     11389        1        1      1.0
# 4     e100005  form1        1        5     13669        1        1      2.0
# ...       ...    ...      ...      ...       ...      ...      ...      ...
# 1631  e101632  form1        0        1      8760        1        1      3.0
# 1632  e101633  form1        0        1     10568        1        1      3.0
# 1633  e101634  form1        0        1     12449        1        1      3.0
# 1634  e101635  form1        0        1      8209        1        1      3.0
# 1635  e101636  form1        0        1      9311        1        1      3.0
#
#       iresp.4  iresp.5  ...  idur.161  idur.162  idur.163  idur.164  idur.165  \
# 0           1        2  ...        17       102        55        50        17
# 1           1        1  ...        22       121       114        44        36
# 2           4        2  ...        73        34        92        83        50
# 3           4        2  ...        30        93        49        26        57
# 4           4        2  ...        11         0        58       127        63
# ...       ...      ...  ...       ...       ...       ...       ...       ...
# 1631        3        2  ...        10        72        40        10        10
# 1632        3        2  ...        11       116        45        11         7
# 1633        3        2  ...        47       164        28        11        30
# 1634        3        2  ...        14        45        32        14        28
# 1635        3        2  ...        12        61        45        13        14
#
#       idur.166  idur.167  idur.168  idur.169  idur.170
# 0           28        53        82       100        21
# 1           53       120        93        87        29
# 2           30        63        96        79        48
# 3           41        59        41        84        17
# 4           68       164        74        63        17
# ...        ...       ...       ...       ...       ...
# 1631        52        56        47        61        19
# 1632       116        79        59        48        40
# 1633        54        19        27        43        14
# 1634        17        18       109        94        14
# 1635        62        28        51        45        46
#
# [1636 rows x 515 columns]

# %%
# Train Test Split

train, test = train_test_split(data, test_size= 0.2, random_state=23 ,shuffle = True)  
train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)
